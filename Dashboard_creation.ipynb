# %% [markdown]
# # Creating the dashboard

# %%
import dash_core_components as dcc1
import dash_html_components as html1
from dash.dependencies import Input,Output


#BS = "https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css"
#create your application instance by calling function dashboard application
app1=dash.Dash()#external_stylesheets=[BS])


colors={'background':'#111111','text':'#7FDBFF'} #create dictionary of your colors 


#now we need to create a html component as all the webpage running using html page

#defining the HTML component#

app1.layout=html1.Div(style={'backgroundColor': '#5AF5D9'}, children=[
    
    
       html1.Div([
           html1.H2("IPL DASHBOARD",style={'color':'white','padding-top':'10px','margin-left':'2%','display':'inline-block','font-size': '36px','padding-left':'550px',
                                            'text-shadow': '0 0 10px #FF0000, 0 0 50px #0000FF'}),
           html1.Img(src=app1.get_asset_url('ipl_icon.jpg'),style={'position':'relative','float':'right','right':'10px','height':'75px'})
       ],style={'height':'75px','margin':'0px -10px 10px','background-color':'#82CAFA','border-radius':'2px' }),
    
    
        html1.Label("Select a year: ", style = {'display': 'inline-block','color':'blue','font-size': '20px','padding-left':'20px'}),
        dcc1.Dropdown(
          id='input_label',
          options=[                                                    #create multi dropdown menu for my first graph
              {'label':'2008','value':'Rajasthan Royals'},
              {'label':'2009','value':'Deccan Chargers'},
              {'label':'2010','value':'Chennai super Kings'},
              {'label':'2011','value':'Csk'},
              {'label':'2012','value':'Kolkata Knight Riders'},
              {'label':'2013','value':'Mumbai indians'},
              {'label':'2014','value':'Kolkata Knight Rider'},
              {'label':'2015','value':'Mumbai Indians'},   
              {'label':'2016','value':'Sunrisers Hyderabad'},  
              {'label':'2017','value':'mumbai Indians'},  
              {'label':'2018','value':'Chennai Super Kings'},  
              {'label':'2019','value':'Mumbai Indian'},    
                 ],         
         value=' ',
         #multi=True
         style = {'display': 'inline-block','width':'30%'}
                    ),
        html1.Br(),
        html1.Div(id='my-output', style = {'color':'blue','font-size': '30px','padding-left':'20px'}),                                                        
      
    
#****************************/////////////////----FOR 1ST GRAPH-----///////////////////********************************       
dcc1.Graph(id='fig1',figure=fig1, style = {'display': 'inline-block', 'width': '50%',"height" : "75%",'padding-left':'15px',
                                'cursor':'pointer'}),

    
    
#*************************////////////----FOR 2nd GRAPH-------/////////////********************************
dcc1.Graph(figure=fig5,style = {'display': 'inline-block', 'width': '47%',"height" :'75%','padding-left':'7px',
                               'cursor':'pointer'}),
    

    
    
#***********************##########################---FOR 3rd GRAPH--------------#############################*******************'margin-bottom': '50px', 'margin-top': '25px'
dcc1.Graph(figure=fig3,style = {'display': 'inline-block', 'width': '45%',"height" :'75%','padding-left':'15px',
                               'cursor':'pointer'}),

    
    
    
#*******************************************----FOR 4th GRAPH--------------------------**********************************   
dcc1.Graph(figure=fig4,style = {'display': 'inline-block', 'width': '52%',"height" : "75%",'padding-left':'7px',
                                'cursor':'pointer'}),
 
    
    
#*******************************************----FOR 5th GRAPH--------------------------**********************************   
dcc1.Graph(figure=fig6,style = {'display': 'inline-block', 'width': '48%',"height" : "75%",'padding-left':'20px',
                               'cursor':'pointer'}),

    
    
    
#*******************************************----FOR 6th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig17,style = {'display': 'inline-block', 'width': '49%',"height" : "75%",'padding-left':'7px',
                               'cursor':'pointer'}),  #'transform':' rotate(-50deg)'

    
    
#*******************************************----FOR 7th GRAPH--------------------------**********************************   
html.Div(html.P(' Mumbai Indians team is a most successful till now, have won 4 worldcup and followed by this Chennai superkings is also a strong team and it have 5 captains.,This below graph is showing Most toss winning team'),
                 style = {'display': 'inline-block','width': '30%',"height" : "75%",'padding-left':'15px',
                        'cursor':'pointer','background-image': 'linear-gradient(to left, rgba(255,0,0,0), rgba(255,0,0,1))','margin': '12px 12px 12px 12px',
                        'padding': '3px 3px 3px 3px','border': '1px solid','padding': '10px','box-shadow': '10px 10px 5px grey',
                        'border-radius': '15px 50px 30px 5px','text-shadow':'text-shadow: 2px 2px 4px #000000',
                }),
    
    

dcc1.Graph(figure=fig7,style = {'width': '75%',"height" : "150%",'padding-left':'300px',
                               'padding-down':'-30px','cursor':'pointer'}),

    
    
html.Div(html.P(' is entered I have nice phrases with warnings but they are appearing outside boxes or on edges like on picture below. I have no idea what to do.I tried creating empty spaces in boxes like here:'),
        style = {'width': '30%',"height" : "75%",'padding-left':'10px',
                 'cursor':'pointer',  'background-image': 'linear-gradient(to right, rgba(255,0,0,0), rgba(255,0,0,1))','margin': '12px 12px 12px 12px',
                  'padding': '3px 3px 3px 3px','border': '1px solid','padding': '10px','box-shadow':' 5px 10px #888888',
                  'border-radius': '15px 50px 30px'  
                }),
    
    
    


#*******************************************----FOR 8th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig14,style = {'display': 'inline-block', 'width': '36%',"height" : "75%",'padding-left':'15px',
                                'cursor':'pointer'}),
    
    

    
#*******************************************----FOR 9th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig9,style = {'display': 'inline-block', 'width': '61%',"height" :'75%','padding-left':'7px',
                               'cursor':'pointer'}),
  
    
 
    
    
#*******************************************----FOR 10th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig10,style = {'display': 'inline-block', 'width': '39%',"height" : "75%",'padding-left':'15px',
                                'cursor':'pointer'}),

 
    
    
    
#*******************************************----FOR 11th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig11,style = {'display': 'inline-block', 'width': '58%',"height" : "75%",'padding-left':'10px',
                                'cursor':'pointer'}),

  
    
    
    
#*******************************************----FOR 12th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig15,style = {'display': 'inline-block', 'width': '41%',"height" : "75%",'padding-left':'15px',
                                'cursor':'pointer'}),
   

    
    
    
#*******************************************----FOR 14th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig13,style = {'display': 'inline-block', 'width': '56%',"height" : "75%",'padding-left':'10px',
                                'cursor':'pointer'}),



    
    
    
    
#*******************************************----FOR 15th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig8,style = {'display': 'inline-block', 'width': '44%',"height" : "75%",'padding-left':'15px',
                                'cursor':'pointer'}),




#*******************************************----FOR 15th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig2,style = {'display': 'inline-block', 'width': '53%',"height" : "75%",'padding-left':'10px',
                                'cursor':'pointer'}),



    
#*******************************************----FOR 15th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig12,style = {'display': 'inline-block', 'width': '47%',"height" : "75%",'padding-left':'15px',
                                'cursor':'pointer'}),


#*******************************************----FOR 15th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig16,style = {'display': 'inline-block', 'width': '50%',"height" : "75%",'padding-left':'10px',
                                'cursor':'pointer'}),

    
#*******************************************----FOR 15th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig18,style = {'display': 'inline-block', 'width': '50%',"height" : "75%",'padding-left':'10px',
                                'cursor':'pointer'}),
    
    
    
    
#*******************************************----FOR 15th GRAPH--------------------------**********************************
dcc1.Graph(figure=fig19,style = {'display': 'inline-block', 'width': '47%',"height" : "75%",'padding-left':'10px',
                                'cursor':'pointer'}),

    


])






@app1.callback(
    Output(component_id='my-output',component_property='children'),
    [Input(component_id='input_label',component_property='value')]
)
def update_output_div(input_label):
   return 'And the winner of the year is {} '.format(input_label)
    
app1.run_server(debug=True,use_reloader=False)
